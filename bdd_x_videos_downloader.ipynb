# %% [markdown]
# # Import Libraries

# %%
from utils import bdd_x_videos_filtration

# %% [markdown]
# # Download Training Dataset
# ## Filter the Videos

# %% [markdown]
# ### Training Data

# %%
DATASET_TYPE = 'train'
# TEXT_FILE_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}.txt'
TEXT_FILE_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset'
UNZIP_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/unziped_folders'
FILTERED_VIDEO_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/videos'
DOWNLOAD_OUTPUT_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/downloaded_files'
DOWNLOAD_LINK = f'http://dl.yf.io/bdd100k/video_parts/bdd100k_videos_{DATASET_TYPE}_00.zip'
DOWNLOAD_LEN = 70


bdd_x_videos_filtration(
    text_file_path=TEXT_FILE_PATH,
    unzip_path=UNZIP_PATH,
    filtered_video_path=FILTERED_VIDEO_PATH,
    download_output_path=DOWNLOAD_OUTPUT_PATH,
    download_link=DOWNLOAD_LINK,
    dataset_type=DATASET_TYPE,
    download_len=DOWNLOAD_LEN
)
# Out:
# Training data size: 5588
# Testing data size: 698
# Validation data size: 698
#
# Data size: 6984
# Downloading: bdd100k_videos_train_00.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/downloaded_files/bdd100k_videos_train_00.zip
# Unzipping: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/downloaded_files/bdd100k_videos_train_00.zip to /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/unziped_folders
# Unzipped: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/downloaded_files/bdd100k_videos_train_00.zip
# Deleted zip file: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/downloaded_files/bdd100k_videos_train_00.zip
# Filtered videos from download 0: 261
# Number of filtered videos: 261
# Downloading: bdd100k_videos_train_01.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/train/downloaded_files/bdd100k_videos_train_01.zip
# ...

# %% [markdown]
# ### Test Data

# %%
DATASET_TYPE = 'test'
TEXT_FILE_PATH = '/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/'
UNZIP_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/unziped_folders'
FILTERED_VIDEO_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/videos'
DOWNLOAD_OUTPUT_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/downloaded_files'
DOWNLOAD_LINK = f'http://dl.yf.io/bdd100k/video_parts/bdd100k_videos_{DATASET_TYPE}_00.zip'
DOWNLOAD_LEN = 20

bdd_x_videos_filtration(
    text_file_path=TEXT_FILE_PATH,
    unzip_path=UNZIP_PATH,
    filtered_video_path=FILTERED_VIDEO_PATH,
    download_output_path=DOWNLOAD_OUTPUT_PATH,
    download_link=DOWNLOAD_LINK,
    dataset_type=DATASET_TYPE,
    download_len=DOWNLOAD_LEN
)
# Out:
# Training data size: 5588
# Testing data size: 698
# Validation data size: 698
#
# Data size: 6984
# Downloading: bdd100k_videos_test_00.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/downloaded_files/bdd100k_videos_test_00.zip
# Unzipping: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/downloaded_files/bdd100k_videos_test_00.zip to /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/unziped_folders
# Unzipped: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/downloaded_files/bdd100k_videos_test_00.zip
# Deleted zip file: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/downloaded_files/bdd100k_videos_test_00.zip
# Filtered videos from download 0: 0
# Number of filtered videos: 0
# Downloading: bdd100k_videos_test_01.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/test/downloaded_files/bdd100k_videos_test_01.zip
# ...

# %% [markdown]
# ### Val Data

# %%
DATASET_TYPE = 'val'
TEXT_FILE_PATH = '/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/'
UNZIP_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/unziped_folders'
FILTERED_VIDEO_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/videos'
DOWNLOAD_OUTPUT_PATH = f'/mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/{DATASET_TYPE}/downloaded_files'
DOWNLOAD_LINK = f'http://dl.yf.io/bdd100k/video_parts/bdd100k_videos_{DATASET_TYPE}_00.zip'
DOWNLOAD_LEN = 10

bdd_x_videos_filtration(
    text_file_path=TEXT_FILE_PATH,
    unzip_path=UNZIP_PATH,
    filtered_video_path=FILTERED_VIDEO_PATH,
    download_output_path=DOWNLOAD_OUTPUT_PATH,
    download_link=DOWNLOAD_LINK,
    dataset_type=DATASET_TYPE,
    download_len=DOWNLOAD_LEN
)
'http://dl.yf.io/bdd100k/video_parts/bdd100k_videos_val_07.zip'
# Out:
# Training data size: 5588
# Testing data size: 698
# Validation data size: 698
#
# Data size: 6984
# Downloading: bdd100k_videos_val_00.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/downloaded_files/bdd100k_videos_val_00.zip
# Unzipping: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/downloaded_files/bdd100k_videos_val_00.zip to /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/unziped_folders
# Unzipped: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/downloaded_files/bdd100k_videos_val_00.zip
# Deleted zip file: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/downloaded_files/bdd100k_videos_val_00.zip
# Filtered videos from download 0: 0
# Number of filtered videos: 0
# Downloading: bdd100k_videos_val_01.zip
# Downloaded: /mnt/blockstorage/drivefusion_project/datasets/bdd_x_dataset/val/downloaded_files/bdd100k_videos_val_01.zip
# ...
